# %%
import numpy as np
import pandas as pd
import datatable
import itertools as it
from owlready2 import *
import math
import joblib

import pickle
from sklearn.utils import parallel_backend

#para depurar los que letras que no están en el codigo ascii
import unicodedata
import functools
import spacy
import stanfordnlp
#from spacy_stanfordnlp import StanfordNLPLanguage
from sklearn.decomposition import LatentDirichletAllocation
from sklearn import metrics
#from wiki_dump_reader import Cleaner, iterate
from sklearn.decomposition import TruncatedSVD

from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import pairwise_distances

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import chi2
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize,scale

#from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
#from gensim.models.wrappers import LdaMallet
#from gensim.corpora import Dictionary

#import pyLDAvis
#import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import SVG

import random
from sklearn.externals import joblib


#Operaciones con gráficos
import scattertext as st
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator

import networkx as nx

import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool, LabelSet, ColumnDataSource, Range1d
from bokeh.plotting import figure, show, output_notebook
from sklearn.manifold import TSNE

#import gensim
#import gensim.corpora as corpora
#from gensim.models import CoherenceModel
#from gensim.models import HdpModel

warnings.filterwarnings("ignore")

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from multiprocessing import  Pool
import math
import scipy.sparse as sp
from bayes_opt import BayesianOptimization

import vectorizer
import vectorizer 
importlib.reload(vectorizer)
from vectorizer import  WeightedTfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import *
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .boolean { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .integer { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .string  { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
import  h2o

# %%
from h2o.estimators import H2OXGBoostEstimator, H2ODeepLearningEstimator,H2ORandomForestEstimator,H2OSupportVectorMachineEstimator

# %%
h2o.init(max_mem_size='14G')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# Warning: Your H2O cluster version is too old (7 months and 7 days)! Please download and install the latest version from http://h2o.ai/download/
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         2 mins 50 secs
# H2O cluster timezone:       Europe/Berlin
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.28.0.3
# H2O cluster version age:    7 months and 7 days !!!
# H2O cluster name:           H2O_from_python_rdelaguila_r4cphj
# H2O cluster total nodes:    1
# H2O cluster free memory:    14.00 Gb
# H2O cluster total cores:    12
# H2O cluster allowed cores:  12
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:       {'http': None, 'https': None}
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.7.4 final
# --------------------------  ------------------------------------------------------------------

# %%
from hyperopt import fmin, tpe, hp,Trials

def xgb_cv(space):
    """SVC cross validation.
    This function will instantiate a SVC classifier with parameters C and
    gamma. Combined with data and targets this will in turn be used to perform
    cross validation. The result of cross validation is returned.
    Our goal is to find combinations of C and gamma that maximizes the roc_auc
    metric.
    """
    params = {'max_depth': int(space['max_depth']), 'ntrees': int(space['ntrees']),'min_rows':int(space['min_rows']),'eta':float(space['eta']),
              'learn_rate':float(space['learn_rate']),'sample_rate':float(space['sample_rate']),
              'colsample_bytree':float(space['colsample_bytree']),'reg_lambda':float(space['reg_lambda']),'reg_alpha':float(space['reg_alpha'])}
      
    estimator = H2OXGBoostEstimator(**params,nfolds=2)
    estimator.train(x=vocab,y='target',training_frame=train)
    return estimator.logloss()

def optimize_xgb():
    """Apply Bayesian Optimization to XGB parameters."""
    
    trials = Trials()
    space={"max_depth": hp.uniform('max_depth',4, 40), "ntrees": hp.uniform('x_ntrees',50,400),'min_rows':hp.uniform('x_min_rows',2,50),'eta':hp.uniform('x_eta',0.01,1),
                 'learn_rate':hp.uniform('x_learn_rate',0.01,1),'sample_rate':hp.uniform('x_sample_rate',0.1,0.5),'colsample_bytree':hp.uniform('x_colsample_bytree',0.2,0.8),
                 'reg_lambda':hp.uniform('x_reg_lambda',0,1),'reg_alpha':hp.uniform('x_reg_alpha',0,1)}
    best = fmin(fn=xgb_cv,
            space=space,
            algo=tpe.suggest,
            max_evals=10,
            trials=trials)

    print("Final result:", best)

# %%
from hyperopt import fmin, tpe, hp,Trials

def svm_cv(space):
    """SVC cross validation.
    This function will instantiate a SVC classifier with parameters C and
    gamma. Combined with data and targets this will in turn be used to perform
    cross validation. The result of cross validation is returned.
    Our goal is to find combinations of C and gamma that maximizes the roc_auc
    metric.
    """
    params = {'gamma': float(space['gamma'])}
      
    estimator = H2OSupportVectorMachineEstimator(**params,max_iterations=400)
    estimator.train(x=vocab,y='target',training_frame=train)
    return estimator.logloss()

def optimize_svm():
    """Apply Bayesian Optimization to XGB parameters."""
    
    trials = Trials()
    space={"gamma": hp.uniform('x_gamma',0,1)}
    best = fmin(fn=svm_cv,
            space=space,
            algo=tpe.suggest,
            max_evals=10,
            trials=trials)

    print("Final result:", best)

# %%
list((12,12))
# Out:
# [12, 12]

# %%
from hyperopt import fmin, tpe, hp,Trials

def rf_cv(space):
    """SVC cross validation.
    This function will instantiate a SVC classifier with parameters C and
    gamma. Combined with data and targets this will in turn be used to perform
    cross validation. The result of cross validation is returned.
    Our goal is to find combinations of C and gamma that maximizes the roc_auc
    metric.
    """
    params = {'max_depth': int(space['max_depth']), 
              'ntrees': int(space['ntrees']),'min_rows':int(space['min_rows']),
              'sample_rate':float(space['sample_rate'])}
      
    estimator = H2ORandomForestEstimator(**params,nfolds=2)
    estimator.train(x=vocab,y='target',training_frame=train,validation_frame=test)
    return estimator.logloss()

def optimize_rf():
    """Apply Bayesian Optimization to XGB parameters."""
    
    trials = Trials()
    space={"max_depth": hp.uniform('max_depth',4, 40), 
           "ntrees": hp.uniform('x_ntrees',50,400),
           'min_rows':hp.uniform('x_min_rows',2,50),
           'sample_rate':hp.uniform('x_sample_rate',0.1,0.5)}
    best = fmin(fn=rf_cv,
            space=space,
            algo=tpe.suggest,
            max_evals=10,
            trials=trials)

    print("Final result:", best)

# %%
import joblib
vocab=joblib.load('../objects/amazon/vocab.dtm.final')
newdtm =joblib.load('../objects/amazon/newdtm.final')
corpusnormalizado = joblib.load('../data/processed/amazon/corpus_normalizado.final')
dtm = newdtm.todense()
dtm_scaled = scale(dtm)

# %%
dtm_scaled = pd.DataFrame(data=dtm_scaled, columns=vocab) ##revisar que está bien generado, si no ir al paso anterior

# %%
dtm_scaled['target']=corpusnormalizado.iloc[:,1]

# %%
dtm_scaled.head()
# Out:
#        word  romance  definitely     young      star    follow      bite  \
# 0 -0.135783 -0.12678   -0.164967 -0.140695 -0.182098 -0.152518 -0.196230
# 1 -0.135783 -0.12678   -0.164967 -0.140695 -0.182098 -0.152518 -0.196230
# 2 -0.135783 -0.12678    8.320909 -0.140695 -0.182098 -0.152518 -0.196230
# 3 -0.135783 -0.12678    0.495338 -0.140695 -0.182098 -0.152518  0.311559
# 4 -0.135783 -0.12678   -0.164967 -0.140695 -0.182098 -0.152518 -0.196230
#
#       begin      line     amaze  ...    month     phone  computer    charge  \
# 0 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 1 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 2 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 3  0.627172 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 4 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
#
#        ship    device       usb     right     doesn  target
# 0 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
# 1 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
# 2 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
# 3 -0.102209 -0.115086 -0.107553  0.841012 -0.180336       1
# 4 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
#
# [5 rows x 201 columns]

# %%
dtm_scaled.to_csv('../data/interim/amazon/weighteddtmscaled.csv')
dtm_scaled.head()
# Out:
#        word  romance  definitely     young      star    follow      bite  \
# 0 -0.135783 -0.12678   -0.164967 -0.140695 -0.182098 -0.152518 -0.196230
# 1 -0.135783 -0.12678   -0.164967 -0.140695 -0.182098 -0.152518 -0.196230
# 2 -0.135783 -0.12678    8.320909 -0.140695 -0.182098 -0.152518 -0.196230
# 3 -0.135783 -0.12678    0.495338 -0.140695 -0.182098 -0.152518  0.311559
# 4 -0.135783 -0.12678   -0.164967 -0.140695 -0.182098 -0.152518 -0.196230
#
#       begin      line     amaze  ...    month     phone  computer    charge  \
# 0 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 1 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 2 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 3  0.627172 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
# 4 -0.160721 -0.157255 -0.148642  ... -0.13726 -0.108694 -0.115472 -0.109659
#
#        ship    device       usb     right     doesn  target
# 0 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
# 1 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
# 2 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
# 3 -0.102209 -0.115086 -0.107553  0.841012 -0.180336       1
# 4 -0.102209 -0.115086 -0.107553 -0.196204 -0.180336       1
#
# [5 rows x 201 columns]

# %%
corpusnormalizado.head()
# Out:
#                                         cleaned_text  new_target
# 0  book recommend friend finally read year late w...           1
# 1  need question know child love impair identify ...           1
# 2  keep interest way definitely read jacob s moth...           1
# 3  c w gortner favorite author time wow queen rel...           1
# 4  love book like jk alex delaware series problem...           1

# %%
frame = h2o.upload_file('../data/interim/amazon/weighteddtmscaled.csv',sep=',',header=1)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
frame = frame.drop('C1')

# %%
frame['target']=frame['target'].asfactor()
train,test=frame.split_frame(ratios=[.75])

# %%
optimize_xgb()
# Out:
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# 100%|██████████| 10/10 [11:39<00:00, 69.93s/trial, best loss: 0.19121081286767225]
# Final result: {'max_depth': 25.31635135284238, 'x_colsample_bytree': 0.6837186912399146, 'x_eta': 0.37280030079729876, 'x_learn_rate': 0.31784228852611096, 'x_min_rows': 30.958071805153857, 'x_ntrees': 365.13040377715197, 'x_reg_alpha': 0.5021336494658942, 'x_reg_lambda': 0.8608309636810638, 'x_sample_rate': 0.4476357617029575}

# %%
params= {'colsample_bytree': 0.683, 'eta': 0.37, 'learn_rate': 0.32, 'max_depth': 25, 'min_rows': 31, 'ntrees': 365, 'reg_alpha': 0.5, 'reg_lambda': 0.86, 'sample_rate': 0.44,"nfolds":10}

# %% [markdown]
# train

# %%
model = H2OXGBoostEstimator(**params,seed=123)

# %%
model.train(x=vocab,y='target',training_frame=train)
# Out:
# xgboost Model Build progress: |███████████████████████████████████████████| 100%

# %%
performance = model.model_performance(test)

# %%
performance
# Out:
# ModelMetricsMultinomial: xgboost
# ** Reported on test data. **
#
# MSE: 0.0910176541384989
# RMSE: 0.30169132261054327
# LogLoss: 0.32235662801497633
# Mean Per-Class Error: 0.3511247115590114
#
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
#         0       1     2     Error            Rate
# 0  5311.0   320.0  15.0  0.059334     335 / 5,646
# 1   544.0  5894.0  31.0  0.088885     575 / 6,469
# 2   228.0   211.0  46.0  0.905155       439 / 485
# 3  6083.0  6425.0  92.0  0.107063  1,349 / 12,600
# Top-3 Hit Ratios:
#    k  hit_ratio
# 0  1   0.892937
# 1  2   0.968810
# 2  3   1.000000

# %%
model.save_mojo('../objects/amazon/modelo_xgb_3class')
# Out:
# '/mnt/c/Users/Raúl/Documents/Doctorado/curso NLP/FINAL-NLP-COURSE/FINAL_NLP_COURSE/Scripts Phd/oboe/objects/amazon/modelo_xgb_3class/XGBoost_model_python_1594894675132_11.zip'

# %%
optimize_rf()
# Out:
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# 100%|██████████| 10/10 [31:35<00:00, 189.59s/trial, best loss: 0.35993026188918775]
# Final result: {'max_depth': 28.80119736182124, 'x_min_rows': 14.535096414850619, 'x_ntrees': 290.93063444411723, 'x_sample_rate': 0.4692792054711772}

# %%
params = {'max_depth':29,'min_rows':15,'ntrees':290,'sample_rate':0.46,"nfolds":10}
rfmodel = H2ORandomForestEstimator(**params,seed=123)

# %%
rfmodel.train(x=vocab,y='target',training_frame=train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
performance2 = rfmodel.model_performance(test)

# %%
performance2
# Out:
# ModelMetricsMultinomial: drf
# ** Reported on test data. **
#
# MSE: 0.10166574216609008
# RMSE: 0.3188506580926094
# LogLoss: 0.36319134500938877
# Mean Per-Class Error: 0.3834783421979218
#
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
#         0       1    2     Error            Rate
# 0  5295.0   351.0  0.0  0.062168     351 / 5,646
# 1   571.0  5898.0  0.0  0.088267     571 / 6,469
# 2   219.0   266.0  0.0  1.000000       485 / 485
# 3  6085.0  6515.0  0.0  0.111667  1,407 / 12,600
# Top-3 Hit Ratios:
#    k  hit_ratio
# 0  1   0.888333
# 1  2   0.966190
# 2  3   1.000000

# %%
rfmodel.save_mojo('../objects/amazon/rf_model_3class')
# Out:
# '/mnt/c/Users/Raúl/Documents/Doctorado/curso NLP/FINAL-NLP-COURSE/FINAL_NLP_COURSE/Scripts Phd/oboe/objects/amazon/rf_model_3class/DRF_model_python_1594894675132_22.zip'

# %% [markdown]
# ## Corpus con target original

# %%
newdtm =joblib.load('../objects/amazon/newdtmsinoutliers.final')
corpusnormalizado = joblib.load('../data/processed/amazon/corpus_normalizado_sin_outliers.final')
dtm = newdtm.todense()
dtm_scaled = scale(dtm)

# %%
dtm_scaled = pd.DataFrame(data=dtm_scaled, columns=vocab) ##revisar que está bien generado, si no ir al paso anterior

# %%
corpusnormalizado.head()
# Out:
#                                                             cleaned_text  \
# 0  book recommend friend finally read year late wow wait start addres...
# 1  need question know child love impair identify mental illness behav...
# 2  keep interest way definitely read jacob s mother teacher father da...
# 3  c w gortner favorite author time wow queen release day novel local...
# 4  love book like jk alex delaware series problem ending closure oh w...
#
#    Topic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
dtm_scaled['target']=corpusnormalizado.iloc[:,1]

# %%
dtm_scaled.head()
# Out:
#       word   romance  definitely     young      star    follow      bite  \
# 0 -0.13585 -0.126799   -0.165010 -0.140686 -0.182012 -0.152454 -0.196233
# 1 -0.13585 -0.126799   -0.165010 -0.140686 -0.182012 -0.152454 -0.196233
# 2 -0.13585 -0.126799    8.323346 -0.140686 -0.182012 -0.152454 -0.196233
# 3 -0.13585 -0.126799    0.495487 -0.140686 -0.182012 -0.152454  0.311557
# 4 -0.13585 -0.126799   -0.165010 -0.140686 -0.182012 -0.152454 -0.196233
#
#       begin      line     amaze  ...     month    phone  computer    charge  \
# 0 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 1 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 2 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 3  0.627127 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 4 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
#
#       ship    device       usb     right     doesn  target
# 0 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
# 1 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
# 2 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
# 3 -0.10224 -0.115103 -0.107591  0.840992 -0.180359       1
# 4 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
#
# [5 rows x 201 columns]

# %%
corpusnormalizado.head()
# Out:
#                                                             cleaned_text  \
# 0  book recommend friend finally read year late wow wait start addres...
# 1  need question know child love impair identify mental illness behav...
# 2  keep interest way definitely read jacob s mother teacher father da...
# 3  c w gortner favorite author time wow queen release day novel local...
# 4  love book like jk alex delaware series problem ending closure oh w...
#
#    Topic
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
dtm_scaled.to_csv('../data/interim/amazon/weighteddtmscaled.csv')
dtm_scaled.head()
# Out:
#       word   romance  definitely     young      star    follow      bite  \
# 0 -0.13585 -0.126799   -0.165010 -0.140686 -0.182012 -0.152454 -0.196233
# 1 -0.13585 -0.126799   -0.165010 -0.140686 -0.182012 -0.152454 -0.196233
# 2 -0.13585 -0.126799    8.323346 -0.140686 -0.182012 -0.152454 -0.196233
# 3 -0.13585 -0.126799    0.495487 -0.140686 -0.182012 -0.152454  0.311557
# 4 -0.13585 -0.126799   -0.165010 -0.140686 -0.182012 -0.152454 -0.196233
#
#       begin      line     amaze  ...     month    phone  computer    charge  \
# 0 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 1 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 2 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 3  0.627127 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
# 4 -0.160685 -0.157324 -0.148637  ... -0.137277 -0.10866 -0.115433 -0.109634
#
#       ship    device       usb     right     doesn  target
# 0 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
# 1 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
# 2 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
# 3 -0.10224 -0.115103 -0.107591  0.840992 -0.180359       1
# 4 -0.10224 -0.115103 -0.107591 -0.196195 -0.180359       1
#
# [5 rows x 201 columns]

# %%
frame = h2o.upload_file('../data/interim/amazon/weighteddtmscaled.csv',sep=',',header=1)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
frame = frame.drop('C1')

# %%
frame['target']=frame['target'].asfactor()
train,test=frame.split_frame(ratios=[.75])

# %%
optimize_xgb()
# Out:
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# xgboost Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# 100%|██████████| 10/10 [04:50<00:00, 29.07s/trial, best loss: 0.11987606017933979]
# Final result: {'max_depth': 8.871928918497767, 'x_colsample_bytree': 0.47822463400466264, 'x_eta': 0.6641578300169094, 'x_learn_rate': 0.6566707140048567, 'x_min_rows': 3.534424338582351, 'x_ntrees': 349.66826839664617, 'x_reg_alpha': 0.9717095117905109, 'x_reg_lambda': 0.800624365122051, 'x_sample_rate': 0.4200144816786674}

# %%
params= {'colsample_bytree': 0.70, 'eta': 0.41, 'learn_rate': 0.73, 'max_depth': 18, 'min_rows': 9, 'ntrees': 126, 'reg_alpha': 0.91, 'reg_lambda': 0.86, 'sample_rate': 0.3072,"nfolds":10}

# %% [markdown]
# train

# %%
model = H2OXGBoostEstimator(**params,seed=123)

# %%
model.train(x=vocab,y='target',training_frame=train)
# Out:
# xgboost Model Build progress: |███████████████████████████████████████████| 100%

# %%
performance = model.model_performance(test)

# %%
performance
# Out:
# ModelMetricsBinomial: xgboost
# ** Reported on test data. **
#
# MSE: 0.017114844569077456
# RMSE: 0.1308237156217383
# LogLoss: 0.0678986603764839
# Mean Per-Class Error: 0.024402795014797363
# AUC: 0.9932535930845249
# AUCPR: 0.9116899442823632
# Gini: 0.9865071861690498
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.999906      0.032370                 0.032370  216.994220
# 1           0.999890      0.031214                 0.063584  216.994220
# 2           0.999876      0.032370                 0.095954  216.994220
# 3           0.999859      0.031214                 0.127168  216.994220
# 4           0.999839      0.032370                 0.159538  216.994220
# 5           0.999725      0.158382                 0.317919  216.994220
# 6           0.999549      0.158382                 0.476301  216.994220
# 7           0.999186      0.160694                 0.636994  216.994220
# 8           0.982841      0.309827                 0.946821  202.329007
# 9           0.775695      0.041618                 0.988439  -56.936634
# 10          0.568925      0.003468                 0.991908  -97.680530
# 11          0.520044      0.001156                 0.993064  -97.813833
# 12          0.448621      0.004624                 0.997688  -95.251023
# 13          0.390371      0.001156                 0.998844  -98.903134
# 14          0.349584      0.000000                 0.998844 -100.000000
# 15          0.314592      0.001156                 1.000000  -98.847294
#
#     cumulative_gain
# 0        216.994220
# 1        216.994220
# 2        216.994220
# 3        216.994220
# 4        216.994220
# 5        216.994220
# 6        216.994220
# 7        216.994220
# 8        212.041185
# 9        147.064775
# 10        80.478461
# 11        64.829319
# 12        42.556546
# 13        24.041216
# 14        11.018648
# 15         0.000000

# %%
model.save_mojo('../objects/amazon/modelo_xgb_2class')
# Out:
# '/mnt/c/Users/Raúl/Documents/Doctorado/curso NLP/FINAL-NLP-COURSE/FINAL_NLP_COURSE/Scripts Phd/oboe/objects/amazon/modelo_xgb_2class/XGBoost_model_python_1594894675132_11.zip'

# %%
optimize_rf()
# Out:
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# drf Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █| 100%
# 100%|██████████| 10/10 [15:04<00:00, 90.50s/trial, best loss: 0.26073027899700246]
# Final result: {'max_depth': 30.729603386936066, 'x_min_rows': 11.678592799124585, 'x_ntrees': 264.9626002418294, 'x_sample_rate': 0.3174822951309862}

# %%
params = {'max_depth':31,'min_rows':12,'ntrees':265,'sample_rate':0.32,"nfolds":10}
rfmodel = H2ORandomForestEstimator(**params,seed=123)

# %%
rfmodel.train(x=vocab,y='target',training_frame=train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
performance2 = rfmodel.model_performance(test)

# %%
performance2
# Out:
# ModelMetricsBinomial: drf
# ** Reported on test data. **
#
# MSE: 0.0733047928106214
# RMSE: 0.27074857859390766
# LogLoss: 0.25992654233236817
# Mean Per-Class Error: 0.08731382477503091
# AUC: 0.9647511816180405
# AUCPR: 0.9710425778876726
# Gini: 0.929502363236081
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4553874649993872:
#                0       1   Error               Rate
# 0      0  5223.0   436.0   0.077     (436.0/5659.0)
# 1      1   663.0  6075.0  0.0984     (663.0/6738.0)
# 2  Total  5886.0  6511.0  0.0887   (1099.0/12397.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold        value    idx
# 0                        max f1   0.455387     0.917050  212.0
# 1                        max f2   0.203919     0.931128  295.0
# 2                  max f0point5   0.649352     0.934802  165.0
# 3                  max accuracy   0.455387     0.911350  212.0
# 4                 max precision   0.997772     1.000000    0.0
# 5                    max recall   0.050894     1.000000  383.0
# 6               max specificity   0.997772     1.000000    0.0
# 7              max absolute_mcc   0.530347     0.822486  193.0
# 8    max min_per_class_accuracy   0.389688     0.908578  228.0
# 9   max mean_per_class_accuracy   0.530347     0.912686  193.0
# 10                      max tns   0.997772  5659.000000    0.0
# 11                      max fns   0.997772  6726.000000    0.0
# 12                      max fps   0.017669  5659.000000  399.0
# 13                      max tps   0.050894  6738.000000  383.0
# 14                      max tnr   0.997772     1.000000    0.0
# 15                      max fnr   0.997772     0.998219    0.0
# 16                      max fpr   0.017669     1.000000  399.0
# 17                      max tpr   0.050894     1.000000  383.0
# Gains/Lift Table: Avg response rate: 54.35 %, avg score: 54.36 %
#       group  cumulative_data_fraction  lower_threshold      lift  \
# 0         1                  0.
# '/mnt/c/Users/Raúl/Documents/Doctorado/curso NLP/FINAL-NLP-COURSE/FINAL_NLP_COURSE/Scripts Phd/oboe/objects/amazon/rf_model_2class/DRF_model_python_1594894675132_5163.zip'

# %%
xgbmodel = h2o.upload_mojo('../objects/amazon/modelo_xgb_2class/XGBoost_model_python_1594894675132_11.zip')
# Out:
# generic Model Build progress: |███████████████████████████████████████████| 100%
# Model Details
# =============
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  Generic_model_python_1599929472018_2
#
#
# Model Summary:
#      number_of_trees
# 0              365.0
# ModelMetricsMultinomialGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.05828545815207381
# RMSE: 0.2414238143847326
# LogLoss: 0.195331023328084
# Mean Per-Class Error: 0.273913986567434
#
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
#          0        1      2     Error            Rate
# 0  16538.0    480.0    5.0  0.028491    485 / 17,023
# 1   1012.0  17977.0   36.0  0.055085  1,048 / 19,025
# 2    545.0    453.0  354.0  0.738166     998 / 1,352
# 3  18095.0  18910.0  395.0  0.067674  2,531 / 37,400
# Top-3 Hit Ratios:
#    k  hit_ratio
# 0  1   0.932326
# 1  2   0.980829
# 2  3   1.000000
# ModelMetricsMultinomialGeneric: generic
# ** Reported on cross-validation data. **
#
# MSE: 0.09232381593141849
# RMSE: 0.30384834363777347
# LogLoss: 0.32341603919407735
# Mean Per-Class Error: 0.3585024003687994
#
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
#          0        1      2     Error            Rate
# 0  15891.0   1108.0   24.0  0.066498  1,132 / 17,023
# 1   1600.0  17362.0   63.0  0.087411  1,663 / 19,025
# 2    588.0    658.0  106.0  0.921598   1,246 / 1,352
# 3  18079.0  19128.0  193.0  0.108048  4,041 / 37,400
# Top-3 Hit Ratios:
#    k  hit_ratio
# 0  1   0.891952
# 1  2   0.968636
# 2  3   1.000000
# Cross-Validation Metrics Summary:
#                                   mean            sd   cv_1_valid  cv_2_valid  \
# 0                 accuracy  0.89197505  0.0032846013    0.8955507  0.89329684
# 1                      err  0.10802496  0.0032846013  0.104449265  0.10670315
# 2                err_count       404.1     16.120726        385.0       390.0
# 3                  logloss  0.32334346   0.010354816   0.31658658   0.3127364
# 4      max_per_class_error  0.92143613   0.023075921   0.90082645   0.9338235
# 5  mean_per_class_accuracy   0.6415634  0.0055232495   0.64851326  0.63913316
# 6     mean_per_class_error  0.35843658  0.0055232495   0.35148674   0.3608668
# 7                      mse  0.09230401  0.0026574298    0.0905261  0.09019607
# 8                       r2   0.7075503   0.009523632    0.7078705  0.71618015
# 9                     rmse  0.30378747  0.0043697995   0.30087554  0.30032662
#
#    cv_3_valid  cv_4_valid  cv_5_valid  cv_6_valid   cv_7_valid  cv_8_valid  \
# 0    0.895673  0.88977426  0.89086497   0.8912872   0.88618314   0.8894433
# 1  0.10432705  0.11022577    0.109135  0.10871282  0.113816835  0.11055672
# 2       393.0       415.0       405.0       413.0        430.0       421.0
# 3   0.3122613   0.3251983  0.32019734  0.33499795   0.33972543   0.3219848
# 4  0.93430656  0.91729325   0.9259259   0.9206349   0.88148147  0.90909094
# 5   0.6399943  0.64100116   0.6436286  0.63975954   0.64964527   0.6428106
# 6  0.36000565   0.3589988   0.3563714   0.3602405    0.3503547  0.35718945
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#      variable  relative_importance  scaled_importance  percentage
# 0        book         13084.668945           1.000000    0.248692
# 1        read          5190.313477           0.396671    0.098649
# 2       story          3177.921387           0.242874    0.060401
# 3        love          1937.988892           0.148111    0.036834
# 4       great          1847.423584           0.141190    0.035113
# 5   character          1638.816895           0.125247    0.031148
# 6        good          1556.102783           0.118926    0.029576
# 7        work          1407.435913           0.107564    0.026750
# 8        like          1021.375366           0.078059    0.019413
# 9      series           984.217346           0.075219    0.018706
# 10      write           825.414124           0.063083    0.015688
# 11        buy           814.065979           0.062215    0.015472
# 12   interest           673.286072           0.051456    0.012797
# 13     author           654.966492           0.050056    0.012449
# 14      movie           595.315063           0.045497    0.011315
# 15       well           570.716309           0.043617    0.010847
# 16       easy           554.810181           0.042402    0.010545
# 17       time           547.437134           0.041838    0.010405
# 18      enjoy           533.520874           0.040775    0.010140
# 19       find           507.619629           0.038795    0.009648
# See the whole table with table.as_data_frame()

# %%
xgbmodel.varimp_plot()
# Out:
# ---------------------------------------------------------------------------
# H2OValueError                             Traceback (most recent call last)
# <ipython-input-6-e05d142133c9> in <module>
# ----> 1 xgbmodel.varimp_plot()
#
# ~/anaconda3/lib/python3.7/site-packages/h2o/model/model_base.py in varimp_plot(self, num_of_features, server)
#    1411             if not server: plt.show()
#    1412         else:
# -> 1413             raise H2OValueError("A variable importances plot is not implemented for this type of model")
#    1414
#    1415
#
# H2OValueError: A variable importances plot is not implemented for this type of model

# %%
rfmodel = h2o.upload_mojo('../objects/amazon/rf_model_2class/DRF_model_python_1594894675132_5163.zip')
# Out:
# generic Model Build progress: |███████████████████████████████████████████| 100%
# Model Details
# =============
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  Generic_model_python_1599929472018_3
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0              265.0                     265.0             691385.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0       31.0       31.0        31.0       135.0       255.0    196.00377
# ModelMetricsBinomialGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.07323749045037865
# RMSE: 0.2706242606463409
# LogLoss: 0.2595234774591883
# Mean Per-Class Error: 0.08843304259168328
# AUC: 0.965296155925658
# AUCPR: 0.9667661995417176
# Gini: 0.930592311851316
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.45824947235680064:
#                 0        1   Error               Rate
# 0      0  15593.0   1417.0  0.0833   (1417.0/17010.0)
# 1      1   1943.0  18650.0  0.0944   (1943.0/20593.0)
# 2  Total  17536.0  20067.0  0.0894   (3360.0/37603.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.458249      0.917364  211.0
# 1                        max f2   0.202798      0.928361  297.0
# 2                  max f0point5   0.726601      0.934855  139.0
# 3                  max accuracy   0.458249      0.910645  211.0
# 4                 max precision   0.997023      1.000000    0.0
# 5                    max recall   0.040080      1.000000  389.0
# 6               max specificity   0.997023      1.000000    0.0
# 7              max absolute_mcc   0.483251      0.820690  204.0
# 8    max min_per_class_accuracy   0.427192      0.909241  219.0
# 9   max mean_per_class_accuracy   0.483251      0.911567  204.0
# 10                      max tns   0.997023  17010.000000    0.0
# 11                      max fns   0.997023  20446.000000    0.0
# 12                      max fps   0.015699  17010.000000  399.0
# 13                      max tps   0.040080  20593.000000  389.0
# 14                      max tnr   0.997023      1.000000    0.0
# 15                      max fnr   0.997023      0.992862    0.0
# 16                      max fpr   0.015699      1.000000  399.0
# 17                      max tpr   0.040080      1.000000  389.0
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.455080065921933:
#                 0        1   Error               Rate
# 0      0  15614.0   1396.0  0.0821   (1396.0/17010.0)
# 1      1   1972.0  18621.0  0.0958   (1972.0/20593.0)
# 2  Total  17586.0  20017.0  0.0896   (3368.0/37603.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.455080      0.917065  216.0
# 1                        max f2   0.199806      0.928119  303.0
# 2                  max f0point5   0.675299      0.934318  164.0
# 3                  max accuracy   0.455080      0.910433  216.0
# 4                 max precision   0.997085      1.000000    0.0
# 5                    max recall   0.036651      1.000000  392.0
# 6               max specificity   0.997085      1.000000    0.0
# 7              max absolute_mcc   0.455080      0.820145  216.0
# 8    max min_per_class_accuracy   0.425919      0.908561  223.0
# 9   max mean_per_class_accuracy   0.516856      0.911405  201.0
# 10                      max tns   0.997085  17010.000000    0.0
# 11                      max fns   0.997085  20529.000000    0.0
# 12                      max fps   0.015837  17010.000000  399.0
# 13                      max tps   0.036651  20593.000000  392.0
# 14                      max tnr   0.997085      1.000000    0.0
# 15                      max fnr   0.997085      0.996892    0.0
# 16                      max fpr   0.015837      1.000000  399.0
# 17                      max tpr   0.036651      1.000000  392.0
# Gains/Lift Table: Avg response rate: 54.76 %, avg score: 54.79 %
#      group  cumulative_data_fraction  lower_threshold      lift  \
# 0        1                  0.010026         0.992644  1.826009
# 1        2                  0.020025         0.990015  1.826009
# 2        3                  0.030024         0.987791  1.826009
# 3        4                  0.040023         0.985559  1.826009
# 4        5                  0.050023         0.983496  1.826009
# 5        6                  0.100019         0.972731  1.824066
# 6        7                  0.150015         0.962193  1.822124
# 7        8                  0.200011         0.948860  1.818239
# 8        9                  0.300003         0.901851  1.805126
# 9       10                  0.399995         0.830382  1.741993
# 10      11                  0.500013         0.649680  1.497318
# 11      12                  0.600005         0.249931  0.726518
# 12      13                  0.699997         0.198530  0.385599
# 13      14                  0.799989         0.161988  0.124324
# 14      15                  0.899981         0.086765  0.049050
# 15      16                  1.000000         0.012245  0.024761
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          1.826009       1.000000  0.994718                  1.000000
# 1          1.826009       1.000000  0.991255                  1.000000
# 2          1.826009       1.000000  0.988945                  1.000000
# 3          1.826009       1.000000  0.986660                  1.000000
# 4          1.826009       1.000000  0.984513                  1.000000
# 5          1.825038       0.998936  0.977946                  0.999468
# 6          1.824067       0.997872  0.967609                  0.998936
# 7          1.822610       0.995745  0.955972                  0.998139
# 8          1.816782       0.988564  0.928037                  0.994947
# 9          1.798086       0.953989  0.867223                  0.984708
# 10         1.737923       0.819995  0.763554                  0.951760
# 11         1.569371       0.397872  0.401261                  0.859454
# 12         1.400273       0.211170  0.210103                  0.766849
# 13         1.240790       0.068085  0.181533                  0.679509
# 14         1.108382       0.026862  0.126160                  0.606997
# 15         1.000000       0.013560  0.056149                  0.547642
#
#     cumulative_score  capture_rate  cumulative_capture_rate       gain  \
# 0           0.994718      0.018307                 0.018307  82.600884
# 1           0.992989      0.018259                 0.036566  82.600884
# 2           0.991642      0.018259                 0.054824  82.600884
# 3           0.990398      0.018259                 0.073083  82.600884
# 4           0.989221      0.018259                 0.091342  82.600884
# 5           0.983585      0.091196                 0.182538  82.406628
# 6           0.978260      0.091099                 0.273637  82.212371
# 7           0.972689      0.090905                 0.364541  81.823859
# 8           0.957806      0.180498                 0.545040  80.512629
# 9           0.935162      0.174185                 0.719225  74.199301
# 10          0.900835      0.149760                 0.868985  49.731754
# 11          0.817580      0.072646                 0.941631 -27.348159
# 12          0.730804      0.038557                 0.980187 -61.440133
# 13          0.662150      0.012431                 0.992619 -87.567599
# 14          0.602599      0.004905                 0.997523 -95.095029
# 15          0.547944      0.002477                 1.000000 -97.523891
#
#     cumulative_gain
# 0         82.600884
# 1         82.600884
# 2         82.600884
# 3         82.600884
# 4         82.600884
# 5         82.503781
# 6         82.406662
# 7         82.260981
# 8         81.678248
# 9         79.808636
# 10        73.792300
# 11        56.937051
# 12        40.027309
# 13        24.079006
# 14        10.838229
# 15         0.000000
# Cross-Validation Metrics Summary:
#                                    mean            sd  cv_1_valid  cv_2_valid  \
# 0                  accuracy   0.9106928    0.00524072  0.90393955  0.90827435
# 1                       auc  0.96549845  0.0029416562  0.96539205   0.9659959
# 2                     aucpr  0.97059244   0.002977612  0.97241503   0.9716673
# 3                       err  0.08930716    0.00524072  0.09606044  0.09172564
# 4                 err_count       335.7     17.938475       356.0       337.0
# 5                  f0point5   0.9230438    0.00845278   0.9081682  0.91209644
# 6                        f1   0.9176909   0.004731525   0.9134662  0.91758376
# 7                        f2  0.91247326   0.007033958   0.9188264   0.9231375
# 8            lift_top_group   1.8261039   0.020212794   1.8193421   1.8152174
# 9                   logloss   0.2598896   0.006909874     0.26196   0.2619117
# 10      max_per_class_error  0.09918085   0.011185219  0.11863391  0.11454546
# 11                      mcc  0.82045686   0.010821598  0.80573726   0.8144093
# 12  mean_per_class_accuracy   0.9108246   0.005909195  0.90190053    0.906166
# 13     mean_per_class_error  0.08917537   0.005909195  0.09809948  0.09383399
# 14                      mse  0.07330763  0.0027126796  0.07428283  0.07401378
# 15                   pr_auc  0.97059244   0.002977612  0.97241503   0.9716673
# 16                precision  0.92668945    0.01215836   0.9046702  0.90847456
# 17                       r2  0.70404357   0.010808566  0.69990975   0.7008449
# 18                   recall  0.90906835   0.010420484   0.9224349   0.9268775
# 19                     rmse  0.27071184    0.00502509  0.27254876  0.27205473
#
#      cv_3_valid   cv_4_valid   cv_5_valid   cv_6_valid  cv_7_valid  \
# 0     0.9161819    0.9128368    0.9095047    0.9198953    0.905327
# 1    0.96873593    0.9672579   0.96330345    0.9700769  0.96115047
# 2     0.9736006   0.97524387    0.9682109   0.97002476   0.9679012
# 3   0.083818085   0.08716323   0.09049532   0.08010471  0.09467299
# 4         317.0        330.0        338.0        306.0       359.0
# 5     0.9357625    0.9263006   0.92442375    0.9299951  0.91823524
# 6      0.922437     0.920977    0.9170756   0.92594385   0.9112923
# 7     0.9094857   0.91571426   0.90984327    0.9219277   0.9044536
# 8     1.8078394    1.7960151    1.8087167    1.8356559   1.8506589
# 9     0.2521749   0.25549522   0.26452595   0.24748671  0.26931265
#
#     training_logloss  training_auc  training_pr_auc  training_lift  \
# 0                NaN           NaN              NaN            NaN
# 1           0.574427      0.931215         0.505587       1.783061
# 2           0.434662      0.937533         0.613407       1.797982
# 3           0.353763      0.944260         0.691790       1.806835
# 4           0.306031      0.950240         0.742902       1.814606
# 5           0.290233      0.954070         0.783631       1.816197
# 6           0.278603      0.956823         0.816219       1.819525
# 7           0.271934      0.957278         0.845914       1.823810
# 8           0.268299      0.958672         0.876824       1.825039
# 9           0.265798      0.959551         0.889149       1.826009
# 10          0.263868      0.960465         0.899248       1.826009
# 11          0.262319      0.961008         0.907737       1.826009
# 12          0.261099      0.961579         0.918708       1.826009
# 13          0.261812      0.962021         0.929886       1.826009
# 14          0.261725      0.962020         0.935218       1.826009
# 15          0.261271      0.962355         0.939293       1.826009
# 16          0.261074      0.962506         0.942088       1.826009
# 17          0.262446      0.962728         0.945392       1.826009
# 18          0.262312      0.962852         0.941504       1.826009
# 19          0.262971      0.962765         0.952885       1.826009
#
#     training_classification_error
# 0                             NaN
# 1                        0.112533
# 2                        0.110607
# 3                        0.104253
# 4                        0.099729
# 5                        0.097804
# 6                        0.095399
# 7                        0.095323
# 8                        0.095080
# 9                        0.094705
# 10                       0.094035
# 11                       0.092546
# 12                       0.092998
# 13                       0.092386
# 14                       0.092439
# 15                       0.092227
# 16                       0.091801
# 17                       0.092147
# 18                       0.092626
# 19                       0.092360
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#      variable  relative_importance  scaled_importance  percentage
# 0        book        180068.703125           1.000000    0.282915
# 1        read         92527.992188           0.513848    0.145376
# 2       story         72994.531250           0.405370    0.114685
# 3   character         36380.816406           0.202039    0.057160
# 4        work         24929.304688           0.138443    0.039168
# 5       write         22883.845703           0.127084    0.035954
# 6      author         21137.634766           0.117386    0.033210
# 7      series         20436.533203           0.113493    0.032109
# 8    interest         17089.091797           0.094903    0.026850
# 9       enjoy         16121.714844           0.089531    0.025330
# 10        buy         10944.596680           0.060780    0.017196
# 11      novel          7625.115234           0.042346    0.011980
# 12       life          6587.174805           0.036581    0.010349
# 13      movie          6388.960938           0.035481    0.010038
# 14        end          6319.472656           0.035095    0.009929
# 15       plot          6083.002930           0.033782    0.009557
# 16       love          5298.844238           0.029427    0.008325
# 17     reader          4940.984863           0.027439    0.007763
# 18     recipe          4261.817383           0.023668    0.006696
# 19      world          4178.661621           0.023206    0.006565
# See the whole table with table.as_data_frame()

# %%
rfmodel.varimp_plot()
# Out:
# ---------------------------------------------------------------------------
# H2OValueError                             Traceback (most recent call last)
# <ipython-input-8-aeb6d84d12fc> in <module>
# ----> 1 rfmodel.varimp_plot()
#
# ~/anaconda3/lib/python3.7/site-packages/h2o/model/model_base.py in varimp_plot(self, num_of_features, server)
#    1411             if not server: plt.show()
#    1412         else:
# -> 1413             raise H2OValueError("A variable importances plot is not implemented for this type of model")
#    1414
#    1415
#
# H2OValueError: A variable importances plot is not implemented for this type of model

# %%
h2o.shutdown()
